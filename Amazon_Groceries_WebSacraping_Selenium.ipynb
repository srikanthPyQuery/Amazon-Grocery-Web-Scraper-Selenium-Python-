# %% [markdown]
# # Amazon Grocery Web Scraper (Selenium + Python)
#
# ### Setting up environment
# drivers and services
# ##### import selenium webdrivers and services
# ##### import chromedrivermanager
# libraries
# ##### import time,numpy, pandas

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time
import numpy as np
import pandas as pd

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.amazon.in")
time.sleep(2)
## create empty lists for extracting required data
Product_Name=[]
Price=[]
Rating=[]
Raters=[]

#send keyword (groceries) to search bar
enter_bar = driver.find_element(By.XPATH, "//input[@id='twotabsearchtextbox']")
enter_bar.send_keys("groceries")
#click on search button
search_btn = driver.find_element(By.XPATH, "//input[@id='nav-search-submit-button']").click()
time.sleep(2)


#Based on your interest sort the products . In this code(used sort option and selected "bestseller" )
sortby_btn = driver.find_element(By.XPATH, "//span[@class='a-button a-button-dropdown a-button-small']").click()
bestseller_btn = driver.find_element(By.XPATH, "//a[@id='s-result-sort-select_5']").click()
time.sleep(5)

# ADDING WHILE LOOP HERE
while True:
    products = driver.find_elements(By.XPATH, "//div[@class='a-section a-spacing-small puis-padding-left-small puis-padding-right-small']")
    time.sleep(2)

    for i in products:
        # Product Name
        try:
            name = i.find_element(By.XPATH, ".//a[@class='a-link-normal s-line-clamp-3 s-link-style a-text-normal']").text.strip()
            Product_Name.append(name)
            print("Name:", name)
        except:
            name = np.nan
            Product_Name.append(name)
            pass

        # Price
        try:
            price = i.find_element(By.XPATH, ".//span[@class='a-price-whole']").text.strip()
            Price.append(price)
            print("Price:", price)
        except:
            price = np.nan
            Price.append(price)
            pass

        # Rating
        try:
            rating = i.find_element(By.XPATH, ".//span[@class='a-size-small a-color-base']").text.strip()
            Rating.append(rating)
            print("Rating:", rating)
        except:
            rating = np.nan
            Rating.append(rating)
            pass

        # Raters
        try:
            number_of_ratings = i.find_element(By.XPATH, ".//span[@class='a-size-mini puis-normal-weight-text s-underline-text']").text.strip()
            Raters.append(number_of_ratings)
            print("Raters:", number_of_ratings)
        except:
            number_of_ratings = np.nan
            Raters.append(number_of_ratings)
            pass

#after every page this code will click on next page button untill it find"disabled" 
    try:
        whole_page = driver.find_element(By.XPATH, "//div[@id='search']")
        next_btn = whole_page.find_element(By.XPATH, "//a[contains(@class,'s-pagination-next')]")
        if "disabled" in next_btn.get_attribute("class"):
            print("Reached last page")
            break
        driver.execute_script("arguments[0].click();", next_btn)
        print("➡️ Moving to next page...")
        time.sleep(3)
    except:
        print(" No next page found — stopping.")
        break

driver.quit()
# Out:
# Name: Fresh Onion, 1kg
# Price: 28
# Name: Fresh Potato, 1kg
# Name: Fresh Chilli - Green, 100g
# Price: 7
# Name: Fresh Mushroom, (Approx.180 -200g)
# Price: 48
# Name: Fresh Carrot - Orange, 500g Pack
# Price: 32
# Name: Fortune Premium Kachi Ghani Pure Mustard Oil, 910G PET Bottle (Weight May Vary)
# Price: 299
# Rating: 4.4
# Raters: (34.9K)
# Name: Fresh Ginger (Adrak), 100g
# Price: 12
# Name: Amul Salted Butter Pasteurised, 100 Grams
# Price: 57
# Rating: 4.6
# Raters: (23.1K)
# Name: MAGGI 2-Minute Instant Noodles, Masala Noodles With Goodness Of Iron, Made With Choicest Quality Spices, Favourite Masala Taste, 840/900g Pouch (Pack of 12, 70/75g each) (weight may vary)
# Price: 143
# Rating: 4.4
# Raters: (71.8K)
# Name: Fresh Tomato - Local, 1kg
# Price: 40
# Name: Fortune Premium Kachi Ghani Pure Mustard Oil, 1 ltr pouch
# Price: 185
# Rating: 4.4
# Raters: (36.3K)
# Name: Fresh Curry Leaves, 100 grams Bunch
# Price: 8
# Name: Parry's White Label Sugar, 1kg
# Rating: 4.3
# Raters: (21.6K)
# Name: Fresh Bhendi (Lady Finger), 500g
# Price: 36
# Name: Fresh Cauliflower 1 piece, (400 - 600 g)
# Price: 28
# Name: Saffola Active Refined Cooking oil | Rich in Omega 3 & Oryzanol | Multi-Source Edible Rice Bran & Soyabean oil | 850g/910g pouch[weight may vary]
# Price: 147
# Rating: 4.4
# Raters: (13.4K)
# Name: Quaker Oats 1Kg, Rolled Oats Natural Wholegrain, Nutritious Breakfast Cereals, Dalia Porridge, Easy To Cook, Honey
# Price: 153
# Rating: 4.4
# Raters: (45.5K)
# Name: NIVEA Soft Light Moisturizer, 300 ml | Instant Hydration with Vitamin E & Jojoba Oil | Non-Greasy Cream for Face, Body and Hands | For Smooth, Healthy Skin
# Price: 325
# Rating: 4.4
# Raters: (50.7K)
# Name: MAGGI 2-Minute Instant Noodles, Masala Noodles With Goodness Of Iron, Made With Choicest Quality Spices, Favourite Masala Taste, 70g/75g Pouch (weight may vary)
# Price: 15
# Rating: 4.4
# Raters: (6.3K)
# Name: Fresh Garlic (lehsun) 100g Pack
# Price: 20
# Name: Tata Sampann Unpolished Toor Dal/Arhar Dal, 1kg
# Price: 189
# Rating: 4.5
# Raters: (37.6K)
# Name: Aashirvaad Atta with Multigrains, 5kg pack, The High Fibre Atta
# Price: 304
# Rating: 4.4
# Raters: (17.6K)
# Name: Aashirvaad Salt,with 4-Step advantage, 1kg
# Rating: 4.4
# Raters: (33K)
# Name: Amazon Brand - Vedaka Whole Jeera (Cumin), 200g
# Price: 79
# Rating: 4.4
# Raters: (20.2K)
# Name: Anveshan Wild Forest Honey 1Kg | Raw, Minimally Processed & NMR Tested | Immunity Booster | 100% Pure Natural Honey | No Added Sugar | Forest Harvested | Glass Jar | Lab Certified
# Price: 499
# Rating: 4.4
# Raters: (621)
# Name: Chutnefy | Coriander (Dhaniya) Chutney | 100% Natural Ingredients | Pack of 4*75gms (Dry) | 5-6 Servings/Pack | No Cooking Required | No Artificial Colours or Fillers | Authentic South Indian Recipe
# Price: 500
# Name: TRIPTI Rajma Jammu Red 1kg | Nutritious Kidney Beans | Fresh, Clean & Perfect for Indian Recipes & Daily Cooking
# Price: 249
# Name: Vim Bar - 200gm X 4 | New Superfast Vim Dishwash Bar - Removes burnt & stickiest grease with the power of 100 lemons
# Price: 86
# Rating: 4.4
# Raters: (31.7K)
# Name: Aashirvaad Select Premium Sharbati Atta, 5kg
# Price: 316
# Rating: 4.5
# Raters: (17.9K)
# Name: Fresh Beet Root, 250g
# Price: 16
# Name: FORTUNE Chana Besan, 100% Chana Dal 100% Taste, 500 Gm
# Price: 47
# Rating: 4.4
# Raters: (14.6K)
# Name: Kellogg's Muesli Fruit Nut & Seeds 750G | 12-In-1 Power Breakfast | India'S No. 1 Muesli | Multigrain Breakfast Cereal
# Price: 313
# Rating: 4.4
# Raters: (27.6K)
# Name: Tata Sampann Unpolished Moong Dal (Split), 500g
# Price: 77
# Rating: 4.5
# Raters: (7.3K)
# Name: Fresh Ridge Gourd (Turai) 500g
# Price: 38
# Name: Happilo Premium Natural Whole Cashews 500g Value Pack | Dry Fruits, Kaju, Healthy Snacks | Unsalted Cashew Nuts | Crunchy, Nutritious & Delicious Nuts | Rich in Protein, Magnesium & Phosphorus
# Price: 500
# Rating: 4.2
# Raters: (15.1K)
# Name: Parle Hide and Seek Chocolate Chip Cookies, 200g
# Price: 38
# Rating: 4.4
# Raters: (17.8K)
# Name: Tata Tea Premium 1.5kg, Desh Ki Chai, Unique Blend Crafted For Chai Lovers Across India, Black Tea, Loose Leaves
# Price: 522
# Rating: 4.4
# Raters: (32.4K)
# Name: MAGGI 2-Minute Instant Noodles, Masala Noodles With Goodness Of Iron, Made With Choicest Quality Spices, Favourite Masala Taste, 420g/450g Pouch (weight may vary)
# Price: 81
# Rating: 4.4
# Raters: (26.9K)
# Name: Fresh Bitter Gourd (Karela), 500g
# Price: 28
# Name: Tata Simply Better Pure & Unrefined Cold Pressed Groundnut (Peanut) Oil,Kolhu/Kacchi Ghani/Mara Chekku/Ganuga,Naturally Cholesterol Free,1L,Groundnut Oil Rich Aroma & Flavour Of Real Groundnuts
# Rating: 4.5
# Raters: (4K)
# Name: Britannia Little Hearts, 75g
# Price: 25
# Rating: 4.4
# Raters: (28.2K)
# Name: Fortune 100% Chana Dal Besan,1 kg
# Price: 95
# Rating: 4.4
# Raters: (16.4K)
# Name: Surf Excel Detergent Bar|| Laundry Detergent Bar For Clothes|| Removes Tough Stains|| 4x200 g
# Price: 128
# Rating: 4.4
# Raters: (18.3K)
# Name: Tata Sampann 100% Chana Dal Fine Besan, Gram Flour, 1 Kg
# Price: 111
# Rating: 4.4
# Raters: (30.6K)
# Name: Tata Sampann Unpolished Moong Dal (Split), 1Kg
# Price: 155
# Rating: 4.5
# Raters: (20.3K)
# Name: Cadbury Dairy Milk Chocolate Bar, 12.1 g
# Price: 10
# Rating: 4.4
# Raters: (22K)
# Name: Lay's Potato Chips (40g + 8g Extra) +4.9g = 52.9 Gram, American Style Cream & Onion Flavour, Crunchy Chips & Snacks (Weight May Vary)
# Rating: 4.4
# Raters: (41.5K)
# Name: Tata Sampann Pure Raisins Seedless/Kishmish, 500g, Source Of Potassium, Premium Dry Fruits, Green Raisins
# Price: 257
# Rating: 4.4
# Raters: (4.6K)
# Name: Britannia NutriChoice Sugar Free Cracker Biscuits Pouch, 300 g
# Price: 42
# Rating: 4.3
# Raters: (9.6K)
# Name: Tata Sampann Turmeric Powder With Natural Oils, 200g, Haldi Powder
# Price: 87
# Rating: 4.5
# Raters: (17.7K)
# Name: Fresh Produce Lemon 3 Pieces (90g - 110g).
# Price: 9
# ➡️ Moving to next page...
# Name: Amazon Brand - Vedaka Black Peppercorn (Kali Mirch), 100g
# Price: 119
# Rating: 4.4
# Raters: (13K)
# Name: Fresh Premium Dragon Fruit White,1Pc (Approx.250 -350 g)
# Price: 79
# Name: Tata Sampann Unpolished Kala (Black, Brown) Chana, 1kg
# Price: 115
# Rating: 4.4
# Raters: (17.8K)
# Name: Tata Sampann Masoor Dal, Whole, 1kg
# Rating: 4.5
# Raters: (10.5K)
# Name: Happilo Premium Natural Californian Almonds 200g | Badam Giri, Healthy Snacks, Dry Fruits | Crunchy Nuts | High in Fiber | Rich in Protein | Magnesium | Phosphorus | Dietary Fibre | Zero Cholesterol
# Price: 198
# Rating: 4.2
# Raters: (28.7K)
# Name: Tata Salt Pink Salt, 1kg, Rock Salt for Everyday Cooking, Sendha Salt
# Rating: 4.4
# Raters: (4.9K)
# Name: Parle Monaco Classic Biscuit, 46.4g+5.8g EXTRA = 52.2G
# Price: 9
# Rating: 4.4
# Raters: (5.4K)
# Name: Kinley Strong Soda Original, 750 Ml
# Price: 18
# Rating: 4.4
# Raters: (11.9K)
# Name: FORTUNE Thick Poha, Source of Fibre and Protein, 500grams
# Rating: 4.4
# Raters: (5.1K)
# Name: Cadbury Oreo Chocolate Flavour Creme Sandwich Biscuit, 41.75 g
# Price: 10
# Rating: 4.4
# Raters: (9.4K)
# Name: Amazon Brand - Vedaka Cane Jaggery Powder | 1 Kg Jar
# Price: 119
# Rating: 4.2
# Raters: (12.3K)
# Name: Coca-Cola, 750ml
# Price: 38
# Rating: 4.4
# Raters: (10.7K)
# Name: Wagh Bakri Premium Leaf Tea Pack, 1Kg, Assam
# Price: 513
# Rating: 4.5
# Raters: (12.4K)
# Name: Tata Sampann Unpolished Rajma, 500g
# Price: 89
# Rating: 4.4
# Raters: (6.4K)
# Name: Happilo Premium Dried Afghani Anjeer 200g I Low in Fat | Dry Fruits in Fresh | Healthy Snacks I Rich Source of Vitamins Dietary Fiber | Dry Figs
# Price: 301
# Rating: 4.0
# Raters: (15K)
# Name: Sunfeast Dark Fantasy Yumfills Whoopie Pie, Chocolate Chip, 253g
# Price: 72
# Rating: 4.3
# Raters: (13K)
# Name: Act II Golden Sizzle Popcorn, 30+5G Extra =35g/ 32+5.5=37.5G (Weight May Vary)
# Price: 10
# Rating: 4.4
# Raters: (7.5K)
# Name: MAGGI Nutri-licious Masala Veg Atta Noodles, Instant Noodles with 20 Spices & Herbs, Source of Fibre, Protein & Iron, 290g
# Price: 93
# Rating: 4.4
# Raters: (15.5K)
# Name: Sunfeast YiPPee! Magic Masala, Long, Non-Sticky Instant Noodles | With Real Vegetables 12 in 1 Pack | 720 gram/840g (weight may vary)
# Price: 132
# Rating: 4.3
# Raters: (27.3K)
# Name: Amazon Brand - Vedaka Fennel Whole | 200 G | Saunf | No Added Colours or Preservatives
# Price: 119
# Rating: 4.3
# Raters: (8.6K)
# Name: Aashirvaad Superior MP Atta, 5kg Pack
# Price: 306
# Rating: 4.4
# Raters: (27.4K)
# Name: Parachute Coconut Oil - 1 L Pet Jar
# Price: 475
# Rating: 4.4
# Raters: (47.7K)
# Name: Fresh Premium Mini Orange, 500 gm
# Price: 175
# Name: Lizol Disinfectant Surface & Floor Cleaner Liquid, Citrus - 1 Litre | Suitable for All Floor Cleaner Mops | Kills 99.9% Germs| India's #1 Floor Cleaner
# Price: 189
# Rating: 4.5
# Raters: (13.3K)
# Name: FRESHCON Cooked Rajma | Boiled Ready to Eat Rajma | Ideal For Indian Curry & Quick Salads | Nutritious & Healthy Food | Kidney Beans/Pinto Beans 2kg | 250gm each | Pack of 8
# Price: 533
# Name: FRESHCON Cooked Rajma | Boiled Ready to Eat Rajma | Ideal For Indian Curry & Quick Salads | Nutritious & Healthy Food | Kidney Beans/Pinto Beans 750gm | 250gm each | Pack of 3
# Price: 270
# Name: Minni's Kitchen Garam Masala, No Salt & No Oil, Home made, Traditional, Freshly Grinded, Authentic, No Artifical Addictives, Premium & Strong Aromatic blend of whole spices - 245 gm
# Price: 550
# Name: catch Ginger Garlic Paste, 200 g
# Price: 24
# Rating: 4.3
# Raters: (5.6K)
# Name: Tata Salt Crystal Salt, 1 kg
# Price: 22
# Rating: 4.4
# Raters: (7.9K)
# Name: Lay's American Style Cream & Onion 30.5 Gm./28gram
# Price: 10
# Rating: 4.4
# Raters: (2.7K)
# Name: Parle G Gold 56.25G+12.5=68.75G/75G
# Price: 9
# Rating: 4.4
# Raters: (3.5K)
# Name: Vim Antismell Dishwash Bar with Pudina|| 190 g (Buy 4 Get 1 Free)
# Price: 130
# Rating: 4.4
# Raters: (12.8K)
# Name: Del Monte Tomato Ketchup Spout Pack, 950g
# Price: 69
# Rating: 4.3
# Raters: (21.9K)
# Name: Bingo! Original Style Chilli Sprinkled - Flat Cut Spicy Potato Chips Pack for Snacks, 90g/85gram/90.7G(Weight may vary)
# Price: 31
# Rating: 4.3
# Raters: (17K)
# Name: Britannia Nice Time, 143g or 150g, Brown (Weight May Vary)
# Price: 22
# Rating: 4.4
# Raters: (8.3K)
# Name: Catch Turmeric Powder, 200g
# Price: 58
# Rating: 4.4
# Raters: (9.1K)
# Name: Good Day Britannia Cashew Cookies, 1000 G/ 905 G (Weight May Varie)
# Price: 129
# Rating: 4.4
# Raters: (5.9K)
# Name: Tata Himalayan Rock Pink Salt, 1kg Pouch, Premium Sendha Namak, With Natural Trace Minerals, Low Sodium, Crystal Salt
# Price: 82
# Rating: 4.5
# Raters: (15.5K)
# Name: Tata Sampann Chana Dal, 1kg
# Price: 123
# Rating: 4.5
# Raters: (15.8K)
# Name: Happilo Premium International Omani Dates 250g | Khajur, Khajoor | Dry Fruits | Healthy Snacks | Dry Dates | No Preservatives
# Price: 124
# Rating: 4.1
# Raters: (9.8K)
# Name: Fresh Water Melon - Kiran, 1 Pc (Approx. 2Kg)
# Price: 93
# Name: Tata Sampann, High in Fibre Poha(Thick), 1kg
# Price: 90
# Rating: 4.5
# Raters: (6.6K)
# Name: Fortune Xpert Pro Immunity Oil | Blend of Rice Bran Oil & Refined Sunflower Oil |Oil to Boost Immunity |Healthy Edible Oil 1L Pouch
# Price: 168
# Rating: 4.4
# Raters: (3.5K)
# Name: Sunfeast Marie Light Active, Marie Biscuits with Iron and 6 Vitamins, Tea-Time Biscuits Family Pack, Wheat, 956G/1KG
# Price: 101
# Rating: 4.3
# Raters: (9K)
# Name: Aashirvaad Turmeric Powder, 100g, Natural Golden Turmeric Powder with No Added Flavours and Colours
# Price: 27
# Rating: 4.4
# Raters: (6.9K)
# Name: Amazon Brand - Vedaka Sesame | Whole | 100 G | White Til
# Price: 21
# Rating: 4.4
# Raters: (4K)
# Name: Amazon Brand - Presto! Dishwash Gel | Lemon | 5 Litre Refill Can | Dishwash Liquid | Cuts Through Grease | Safe On Hands
# Price: 499
# Rating: 4.3
# Raters: (32.9K)
# Name: Dhara Filtered Groundnut Oil (0% Trans Fat), 1 L Pouch
# Price: 229
# Rating: 4.4
# Raters: (5.3K)
# Name: Saffola Honey Active, Made with Sundarban Forest Honey, 100% Pure Honey, No sugar adulteration, Natural Immunity booster, 1kg
# Price: 242
# Rating: 4.1
# Raters: (27K)
# Name: Tata Sampann Coriander Powder With Natural Oils, 200g, Dhania Powder
# Price: 84
# Rating: 4.5
# Raters: (11.4K)
# Name: Sunfeast Dark Fantasy Dark Fantasy Choco Fills, 300g
# Price: 101
# Rating: 4.4
# Raters: (33.7K)
# ➡️ Moving to next page...
# Name: Amazon Brand - Vedaka Popular Unpolished Yellow Moong Dal, 500 g|Naturally Rich In Protein||Naturally Cholesterol free
# Price: 79
# Rating: 4.4
# Raters: (6K)
# Name: Britannia Marie Gold Biscuits, 5 N x (190g+20g EXTRA)=1.05kg
# Price: 120
# Rating: 4.4
# Raters: (18.9K)
# Name: Kellogg's Corn Flakes Original 1.2kg/1.15kg | Power of 5: Energy, Protein, Iron, IMMUNO NUTRIENTS, Vitamins B1, B2, B3 & C| Corn Flakes, Breakfast Cereal
# Price: 321
# Rating: 4.5
# Raters: (16.7K)
# Name: Fortune Premium Kachi Ghani Pure Mustard Oil, 4.5 Kg Jar
# Price: 1,395
# Rating: 4.4
# Raters: (19K)
# Name: Happilo Premium Afghani Black Raisins Seedless 250g | Kali Kishmish/Kismis | Dry Fruits, Healthy Snacks | Rich in Fiber, Potassium & Antioxidants | Tasty & Nutritious
# Price: 180
# Rating: 4.2
# Raters: (7.5K)
# Name: Happilo Premium Natural Arabian Dates 500g Pouch | Khajur, Khajoor | Dry Fruits | Dates in Fresh | Healthy Snacks | Rich in Fibre | No Added Sugar
# Price: 126
# Rating: 3.5
# Raters: (2.1K)
# Name: Daawat Rozana Gold Basmati Rice 5Kg| For Everyday Consumption| Cooked Grain Upto 15mm*| Naturally Aged
# Price: 409
# Rating: 4.2
# Raters: (9.4K)
# Name: Britannia Gobbles Bar Cake Fruity Fun, 110 g
# Price: 25
# Rating: 4.3
# Raters: (4.7K)
# Name: Sunfeast Farmlite 5 Seed Digestive Biscuit | High Fibre | Goodness of 5 Power Seeds & Wheat Fibre | 800g/955g ( weight may vary)
# Price: 102
# Rating: 4.2
# Raters: (22.3K)
# Name: Cumin Powder | Catch Jeera Powder, 100g
# Price: 69
# Rating: 4.4
# Raters: (15.1K)
# Name: Daawat Rozana Super Basmati Rice 1Kg| For Everyday Consumption| Cooked Grain Upto 13mm*| Naturally Aged
# Price: 85
# Rating: 4.0
# Raters: (28.4K)
# Name: Tata Sampann Chilli Powder with Natural Oils, 200g, Lal Mirchi Powder, Mirchi Powder
# Rating: 4.4
# Raters: (9.9K)
# Name: Sunfeast Dark Fantasy Choco Fills, 460g Original Filled Cookies with Choco Crème | Perfect Snack
# Price: 158
# Rating: 4.4
# Raters: (24.5K)
# Name: Catch Kashmiri Chilli Powder | Kashmiri Lal Mirchi Powder 100 gram
# Price: 70
# Rating: 4.4
# Raters: (3.5K)
# Name: D'lecta Processed Cheese Slices 200g – 10 Slices
# Price: 80
# Rating: 4.3
# Raters: (4.6K)
# ➡️ Moving to next page...
#  No next page found — stopping.

# %% [markdown]
# ### Create Data Frame to start working on the extracted data

# %%
# Create DataFrame
df = pd.DataFrame({
    "Product": Product_Name,
    "Price": Price,
    "Rating": Rating,
    "Raters": Raters
})

print(df.head())
# Out:
#                               Product Price Rating Raters
# 0                    Fresh Onion, 1kg    28    NaN    NaN
# 1                   Fresh Potato, 1kg   NaN    NaN    NaN
# 2          Fresh Chilli - Green, 100g     7    NaN    NaN
# 3  Fresh Mushroom, (Approx.180 -200g)    48    NaN    NaN
# 4    Fresh Carrot - Orange, 500g Pack    32    NaN    NaN

# %% [markdown]
# ### copy the raw data frame to another data frame to work more

# %%
# copy the raw data frame to another data frame to work more 

df1 = df.copy()

# Make sure the dataFrame copied sucessfully in to new data frame df1
print(df1.head())
print("New Data Frame size :",df1.size,"\nRaw or Original Data Frame size :",df.size)
# Out:
#                               Product Price Rating Raters
# 0                    Fresh Onion, 1kg    28    NaN    NaN
# 1                   Fresh Potato, 1kg   NaN    NaN    NaN
# 2          Fresh Chilli - Green, 100g     7    NaN    NaN
# 3  Fresh Mushroom, (Approx.180 -200g)    48    NaN    NaN
# 4    Fresh Carrot - Orange, 500g Pack    32    NaN    NaN
# New Data Frame size : 468
# Raw or Original Data Frame size : 468

# %% [markdown]
# ### Make sure the dataFrame copied sucessfully in to new data frame df1
# you can use any other availble methods like shape etc

# %%
print(df1.head())
print("New Data Frame size :",df1.size,"\nRaw or Original Data Frame size :",df.size)
# Out:
#                               Product Price Rating Raters
# 0                    Fresh Onion, 1kg    28    NaN    NaN
# 1                   Fresh Potato, 1kg   NaN    NaN    NaN
# 2          Fresh Chilli - Green, 100g     7    NaN    NaN
# 3  Fresh Mushroom, (Approx.180 -200g)    48    NaN    NaN
# 4    Fresh Carrot - Orange, 500g Pack    32    NaN    NaN
# New Data Frame size : 468
# Raw or Original Data Frame size : 468

# %% [markdown]
# ### Small Glimpse of cleaning data
# #### In this section only raw raters column with values like 2.5k , 1.5k converted in to 2500.00, 1500.00

# %%
import regex as re
df1["Raters"]=df1["Raters"].apply(lambda x: re.findall(r"[0-9A-Za-z\.]+",str(x))[0])
df1["Raters"] = df1["Raters"].apply(lambda x: float(x.replace("K", "").replace("k", "")) * 1000 if "k" in x.lower() else float(x))

df1.tail(10)
# Out:
#                                                Product Price Rating   Raters
# 107  Happilo Premium Natural Arabian Dates 500g Pou...   126    3.5   2100.0
# 108  Daawat Rozana Gold Basmati Rice 5Kg| For Every...   409    4.2   9400.0
# 109       Britannia Gobbles Bar Cake Fruity Fun, 110 g    25    4.3   4700.0
# 110  Sunfeast Farmlite 5 Seed Digestive Biscuit | H...   102    4.2  22300.0
# 111            Cumin Powder | Catch Jeera Powder, 100g    69    4.4  15100.0
# 112  Daawat Rozana Super Basmati Rice 1Kg| For Ever...    85    4.0  28400.0
# 113  Tata Sampann Chilli Powder with Natural Oils, ...   NaN    4.4   9900.0
# 114  Sunfeast Dark Fantasy Choco Fills, 460g Origin...   158    4.4  24500.0
# 115  Catch Kashmiri Chilli Powder | Kashmiri Lal Mi...    70    4.4   3500.0
# 116   D'lecta Processed Cheese Slices 200g – 10 Slices    80    4.3   4600.0
